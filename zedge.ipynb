# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import openpyxl
from pathlib import Path

wait_imp = 10
excel_path = Path(r"C:\Users\Owner\Desktop\Book1.xlsx")
wb = openpyxl.load_workbook(excel_path)
ws = wb["Sheet1"]

# Read company name from excelsheet
print ("Step 1 --> Reading Excel-sheet, Please wait....")
s_row     = 4
c_list    = []
avg_val   = []
qnty_list = []
while ws.cell(row = s_row, column= 2).value != None:
    c_name = ws.cell(row = s_row, column= 2).value
    val_1 = ws.cell(row = s_row, column= 4).value
    qnty = ws.cell(row = s_row, column= 5).value
    c_list.append(c_name)
    avg_val.append(val_1)
    qnty_list.append(qnty)
    s_row += 1    
print ("Company name available in Database")
[print('    ->',name) for name in c_list]
time.sleep(2)
print ('\n')
# Out:
# Step 1 --> Reading Excel-sheet, Please wait....
# Company name available in Database
#     -> Yes Bank
#     -> State Bank of India
#     -> IRCTC
#     -> Canara Bank
#     -> Apollo Tyres

# %%
# Out:
# <Response [200]>
# ec8ea47c-2eb2-4c53-802f-89da66ce27d4
# {"message":"success","result":{"id":"ec8ea47c-2eb2-4c53-802f-89da66ce27d4","upload":"https://kakcho.xyz/api/v1/content/ec8ea47c-2eb2-4c53-802f-89da66ce27d4/"}}
# 1.png
# https://kakcho.xyz/api/v1/content/ec8ea47c-2eb2-4c53-802f-89da66ce27d4/
# <Response [201]>
# **********************************************************
# <Response [200]>
# 312bf361-3ea7-45f6-a688-fa550bee9437
# {"message":"success","result":{"id":"312bf361-3ea7-45f6-a688-fa550bee9437","upload":"https://kakcho.xyz/api/v1/content/312bf361-3ea7-45f6-a688-fa550bee9437/"}}
# 10.png
# https://kakcho.xyz/api/v1/content/312bf361-3ea7-45f6-a688-fa550bee9437/
# <Response [201]>
# **********************************************************
# <Response [200]>
# 772714f2-8c01-4073-abe4-85aa04faa752
# {"message":"success","result":{"id":"772714f2-8c01-4073-abe4-85aa04faa752","upload":"https://kakcho.xyz/api/v1/content/772714f2-8c01-4073-abe4-85aa04faa752/"}}
# 100.png
# ...

# %%
CO = webdriver.ChromeOptions()
CO.add_experimental_option('useAutomationExtension', False)
CO.add_argument('--ignore-certificate-errors')
CO.add_argument('--start-maximized')
wd = webdriver.Chrome(options=CO)

print ("Step 2 --> Opening Finance website\n")
wd.implicitly_wait(wait_imp)
wd.get("https://www.moneycontrol.com")
time.sleep(5)
print ("******************************************************************************")
print ("                      Getting Live Stock Value !! Please wait ...\n")


for i in range(len(c_list)):
    src = wd.find_element_by_id ("search_str")
    src.send_keys(c_list[i])
    src.send_keys(Keys.RETURN)
    wd.implicitly_wait(wait_imp)
    s_v = wd.find_element_by_xpath("/html/body/div[10]/div[1]/div[4]/div[1]/div/div[1]/div/div[2]/div[7]/div[2]/div[2]/span[1]")
    ws.cell(row=4+i, column= 3, value = s_v.text)
    
    diff = (avg_val[i] - float(s_v.text))* qnty_list[i]
    per_diff = (diff/(avg_val[i]*qnty_list[i]))*100
    print ("{:>23} -> CMP {:<7} Current P/L->[{:>8.2f}] %P/L -> {:>6.2f}%".format(c_list[i],s_v.text, diff, per_diff))

print ('\n')
print ("Step 3 --> Writing Latest Price into Excel-sheet ....\n")
time.sleep(1)
wb.save(excel_path)

print ("Step 4 --> Successfully Written  \n")
print ("Step 5 --> Closing browser !\n")
print (" ----------------------- FINISHED !! ------------------------")

time.sleep(1)
wd.close()
# Out:
# Step 2 --> Opening Finance website
#
# ******************************************************************************
#                       Getting Live Stock Value !! Please wait ...
#
#                Yes Bank -> CMP 14.11   Current P/L->[11026.96] %P/L ->  87.08%
#     State Bank of India -> CMP 513.95  Current P/L->[-10157.40] %P/L -> -78.31%
#                   IRCTC -> CMP 902.20  Current P/L->[-2152.00] %P/L -> -31.32%
#            Canara Bank  -> CMP 228.60  Current P/L->[  195.00] %P/L ->   6.16%
#            Apollo Tyres -> CMP 242.55  Current P/L->[ 5549.90] %P/L ->  49.87%
#
#
# Step 3 --> Writing Latest Price into Excel-sheet ....
#
# Step 4 --> Successfully Written
#
# Step 5 --> Closing browser !
#
#  ----------------------- FINISHED !! ------------------------

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import openpyxl
from pathlib import Path
p = []
CO = webdriver.ChromeOptions()
CO.add_experimental_option('useAutomationExtension', False)
CO.add_argument('--ignore-certificate-errors')
CO.add_argument('--start-maximized')
wd = webdriver.Chrome(options=CO)
wd.get("https://ms-ignis.github.io/IDPopandMom/")
#src = wd.find_element_by_id ("bits_id")
for i in range(1,2500):
    src = wd.find_element_by_id ("bits_id")
    src =  src.send_keys('000' + str(i))
    l =wd.find_element_by_xpath("//*[@id='btn1']")
    l.click()
    s_v = src = wd.find_element_by_id ("parentlist")
    x = s_v.text
    
    y = x.split('\n')
    
    p.append(y)
    src = wd.find_element_by_id ("bits_id")
    src.clear()

# %%
bits = []
name = []
brach = []
email = []
for i in range(len(p)):
    for j in range(len(p[i])):
        if p[i][j][0:4] == 'BITS':
            bits.append(p[i][j])
        if p[i][j][0:4] == 'Name':
            name.append(p[i][j])
        if p[i][j][0:4] == 'Bran':
            brach.append(p[i][j])
        if p[i][j][0:4] == 'Emai':
            email.append(p[i][j])

# %%
df = pd.DataFrame(list(zip(bits,name,brach,email)))
df
# Out:
#                           0                           1  \
# 0     BITS ID: 2018A7PS0004           Name: Aashay Garg
# 1     BITS ID: 2019A7PS0004     Name: Akash Jyoti Sahoo
# 2     BITS ID: 2020A7PS0004            Name: N Sanshray
# 3     BITS ID: 2018A1TS0005  Name: ANUSHKA SINGH SENGAR
# 4     BITS ID: 2020A7PS0005            Name: SHASHANK P
# ...                     ...                         ...
# 9252  BITS ID: 2019A3PS0177      Name: PRAYAAS KARMAKAR
# 9253  BITS ID: 2018B3A20744          Name: DIVY PRAKASH
# 9254  BITS ID: 2017B4A70883      Name: A.S.K. Chaitanya
# 9255  BITS ID: 2018B1AB0613          Name: PARUSHA JAIN
# 9256  BITS ID: 2018B5A80890           Name: VEDANT SONI
#
#                                        2  \
# 0               Branch: Computer Science
# 1               Branch: Computer Science
# 2               Branch: Computer Science
# 3                       Branch: Chemical
# 4               Branch: Computer Science
# ...

# %%
df.to_csv('file1.csv')

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import openpyxl
from pathlib import Path
x = []
CO = webdriver.ChromeOptions()
CO.add_experimental_option('useAutomationExtension', False)
CO.add_argument('--ignore-certificate-errors')
CO.add_argument('--start-maximized')
wd = webdriver.Chrome(options=CO)
wd.get("https://sharechat.com/")
src = wd.find_element_by_xpath("//*[@id='root']/div[1]/div/main/div/div/div[1]/div/div[3]")
src.click()
time.sleep(5)
#s_v = wd.find_element_by_xpath("//*[@id='root']")
s_v = wd.find_element_by_tag_name("img")
x.append(s_v.get_attribute('src'))

# %%
p = x.split('\n')

# %%
from selenium import webdriver
import os
import urllib
import time

# %%
save_folder = 'pp'
def main():
    #if not os.path.exists('ubbj'):
        #os.mkdir('abcd')
    download_images()
def download_images():
    CO = webdriver.ChromeOptions()
    CO.add_experimental_option('useAutomationExtension', False)
    CO.add_argument('--ignore-certificate-errors')
    CO.add_argument('--start-maximized')
    wd = webdriver.Chrome(options=CO)
    wd.get("https://sharechat.com/")
    src = wd.find_element_by_xpath("//*[@id='root']/div[1]/div/main/div/div/div[1]/div/div[3]")
    src.click()
    time.sleep(5)
    value = 0
    for i in range(3):
        wd.execute_script("scrollBy("+ str(value) +",+1000);")
        value += 1000
        time.sleep(1)
    sub = wd.find_elements_by_tag_name('img')
    p=0
    for i in sub:
        src = i.get_attribute('src')     
        try: 
            if src != None:
                src  = str(src)
                print(src)
                    
                urllib.request.urlretrieve(src, os.path.join((str)p))
                p=p+1
            else:
                raise TypeError
        except Exception as e:              #catches type error along with other errors
                print(f'fail with error {e}')
# Out:
#   File "<ipython-input-19-7c19748e1f92>", line 30
#     urllib.request.urlretrieve(src, os.path.join((str)p))
#                                                       ^
# SyntaxError: invalid syntax

# %%
main()
# Out:
# https://sharechat.com/assets/svg/lazy/logo-wide.svg
# fail with error expected str, bytes or os.PathLike object, not int
# https://cdngoogle.sharechat.com/ProfilePic/2747c90b_1643367378377_sc_thumbnail_v2.jpeg
# fail with error expected str, bytes or os.PathLike object, not int
# https://cdn.sharechat.com/19034440_1644163430761_sc_1644163451751_keyframe_00_01.jpg
# fail with error expected str, bytes or os.PathLike object, not int
# https://sharechat.com/assets/png/engagement-card-bg.png
# fail with error expected str, bytes or os.PathLike object, not int
# https://sharechat.com/assets/png/add-to-home-screen.png
# fail with error expected str, bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ..., bytes or os.PathLike object, not int
# ...

# %%
import os
import re

import requests
from bs4 import BeautifulSoup  # pip install beautifulsoup4
from tqdm import tqdm


def download_uri(uri, dir='./'):
    with open(dir + uri.split('/')[-1], 'wb') as f:
        f.write(requests.get(uri, stream=True).content)


def download_baidu(word):
    url = 'https://image.baidu.com/search/flip?tn=baiduimage&ie=utf-8&word=' + word + '&ct=201326592&v=flip'
    pic_url = re.findall('"objURL":"(.*?)",', requests.get(url).text, re.S)

    i = 0
    for each in pic_url:
        print(pic_url)
        try:
            pic = requests.get(each, timeout=10)
        except requests.exceptions.ConnectionError:
            print('exception')
            continue

        string = 'pictures' + word + '_' + str(i) + '.jpg'
        fp = open(string, 'wb')
        fp.write(pic.content)
        fp.close()
        i += 1


def download_google(word):
    # url = 'https://www.google.com/search?q=' + word + '&client=opera&hs=cTQ&source=lnms&tbm=isch&sa=X&ved=0ahUKEwig3LOx4PzKAhWGFywKHZyZAAgQ_AUIBygB&biw=1920&bih=982'
    url = 'https://www.bing.com/images/search?q=' + word
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    links = soup.find_all('a', {'class': 'thumb'})

    for link in links:
        link = link.get('href')
        s = "curl -s -L -o '%s' '%s'" % (link.split('/')[-1], link)
        os.system(s)


def get_html():
    url = 'http://www.dermnet.com/dn2/allJPG3/'
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    links = soup.find_all('a')

    dir = 'xyz'
    for link in tqdm(links, total=len(links)):
        link = url + link.get('href')
        f = dir + link.split('/')[-1]
        if not os.path.exists(f):
            s = "curl -s -L -o '%s' '%s'" % (f, link)
            os.system(s)


def organize_folders():
    url = 'http://www.dermnet.com/dn2/allJPG3/'
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')
    links = soup.find_all('a')

    dir = "xyz"
    for link in tqdm(links, total=len(links)):
        link = url + link.get('href')
        f = dir + link.split('/')[-1]
        if not os.path.exists(f):
            s = "curl -s -L -o '%s' '%s'" % (f, link)
            os.system(s)

# %%
download_google("honeybee")

# %%
from selenium import webdriver
CO = webdriver.ChromeOptions()
CO.add_experimental_option('useAutomationExtension', False)
CO.add_argument('--ignore-certificate-errors')
CO.add_argument('--start-maximized')
wd = webdriver.Chrome(options=CO)

# %%
def fetch_image_urls(query:str, max_links_to_fetch:int, sleep_between_interactions:int=1):
    from selenium import webdriver
    import time 
    CO = webdriver.ChromeOptions()
    CO.add_experimental_option('useAutomationExtension', False)
    CO.add_argument('--ignore-certificate-errors')
    CO.add_argument('--start-maximized')
    wd = webdriver.Chrome(options=CO)
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)    
    
    # build the google query
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)
        
        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")
        
        for img in thumbnail_results[results_start:number_results]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # extract image urls    
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))

            image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(30)
            return
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)

    return image_urls

# %%
import os 
import requests

# %%
def downloader(link_list, file_path):
    i = 0
    for link in link_list:
        i += 1
        try:
            response = requests.get(link)
            print(response)
            file = open(f"{file_path}/{i}.png", "wb")
            file.write(response.content)
            file.close()
        except:
            pass

# %%
def search_and_download(driver_path:str,number_images=5):
    
    
   
    
    target_folder = 'xyz'
    file_path = target_folder
    search_term = input("enter the search term:")

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    
    res = fetch_image_urls(search_term, number_images, sleep_between_interactions=1)
    downloader(res, file_path)

# %%
search_and_download("chromedriver.exe",5)
# Out:
# enter the search term:shri ram
# Found: 100 search results. Extracting links from 0:100
# Found: 5 image links, done!
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
res = fetch_image_urls("dog", 5, sleep_between_interactions=1)
# Out:
# Found: 48 search results. Extracting links from 0:48
# Found: 5 image links, done!

# %%
res
# Out:
# {'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS66EeVBELXd8Ei_r6RXEJ9FCisZnndVQHbHA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcShgWaNfISOA9x1HAn1OkST9Ss0XB4JtrJRhw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKIQNXzaqSt61Q1LrF_svHpkMCVIGRxmF21A&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTiLVLnCwenBsArkSI8m3-qSxmFBBgGlooGig&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkadcYLGvKXaf623syAbon3-vWi0VcXCHzQA&usqp=CAU'}

# %%
for link in list(res):
        i += 1
        response = requests.get(link)
        print(response)
        file = open(f"{file_path}/{i}.png", "wb")
        file.write(response.content)
        file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0bf16583d9ea> in <module>
# ----> 1 for link in list(res):
#       2         i += 1
#       3         response = requests.get(link)
#       4         print(response)
#       5         file = open(f"{file_path}/{i}.png", "wb")
#
# NameError: name 'res' is not defined

# %%
from selenium import webdriver
import os
import urllib
import urllib.request

import requests
import matplotlib.pyplot as plt

from selenium.webdriver.common.keys import Keys
import time
import openpyxl
from pathlib import Path
import time

# %%
CO = webdriver.ChromeOptions()
CO.add_experimental_option('useAutomationExtension', False)
CO.add_argument('--ignore-certificate-errors')
CO.add_argument('--start-maximized')
wd = webdriver.Chrome(options=CO)
wd.get("https://www.zedge.net/wallpapers")
x = int(input("enter number to be extracted:"))
time.sleep(2)
clicks = wd.find_element_by_xpath("//*[@id='app-root']/div[4]/div/div/div[3]/button")
i = 0
while i < x//18 :
    clicks.click()
    time.sleep(5)
    i += 1
    print(i)

#pop = wd.find_element_by_xpath("/html/body/div[1]/div[5]/div/span[1]/svg")

#op.click()
#time.sleep(5)

# src = wd.find_element_by_xpath("/html/body/div/div[2]/div/section[2]/div/div[1]/div/a[3]/img")#here it is clicking on the language which is hindi currently
# src.click()
# time.sleep(10)
# wall = wd.find_element_by_xpath("/html/body/div[1]/div[4]/div/div/div[1]/div/a[2]")#here it is clicking on the language which is hindi currently
# wall.click()
sub = wd.find_elements_by_tag_name('a')
#print(sub)
url = []
for i in sub:
        src = i.get_attribute('href')     #taking the src from img tag 
        #try: #try and except blog 
        if src != None :
            src  = str(src)
            if src[0:31] ==  "https://www.zedge.net/wallpaper" and len(src) > 33:
                url.append(src)
        else:
            raise TypeError
        #except Exception as e:            
                #count+=1
# Out:
# enter number to be extracted:100
# 1
# 2
# 3
# 4
# 5

# %%
image_url = []
count = 1
for i in url :
    image_content = requests.get(i)
    
#     print(i)
    
    string = str(image_content.text)
    p = string.split("imageUrl")[1].split(',')[0]
    #print(p)
    q = p[3:len(p)-1]
    print(q)
    image_url.append(q)
# Out:
# https://fsb.zobj.net/crop.php?r=oKPydnI8F1DFZHcPQSPmaylopHBmQF_uemJCWcl17ILql7h1UiC7BTWwQYP1ACnNinufb_k9m9laSvFV1Q7UrvliHN_4ryJiYHfJ9cXBL16QJywC7l0PYzEM0-jdDpuE0B4i5CkY39Ke544YgMS86qNgAKyGHje2Q8Aku0jnv17PATprf-uM3EsklbJjqb4Nzf51iJ3OO8KT5D-f
# https://fsa.zobj.net/crop.php?r=QmPCgvOYDDxdK5os1IDcK7qMoVPdfVgIYp3er1NSWkN6mVGckA_nhiIINqnZpiOJRUXEFidEdeiV6Xdgpp6ZQHmpxAQYTdQ33IWSeftDaVFbYqX5qX4hSHwOSAIKehANzWj5Cx2p27Z_o-cv_jC-aQSP0fbyyLFfirpO3x2e0OWex1beDO38pw_DrNrbp_C3CUYgYTUKh1N8lql3
# https://fsb.zobj.net/crop.php?r=Xhs18twaPGfjszKQfUatiOpEN0NZ_PHQKuazv0hZruYTfHiakfvV8YRbNjE-eyVbPlU1Ma8JlAYxi74yHNx56oG6slPulgaz4-m2NMemb5daGxtXnK0riEr3zkpsob2UUR7JhB4LX8Y6cAuaGPGQ6WJxx5m_QN0sUPJsP6zdMqrVQKmOAmTbtkaYKeij28UkABhkupSp9kxDPoVv
# https://fsa.zobj.net/crop.php?r=u0NN34GZT-RpAJbm7pz5II350naS2iWJwZ5yz6ZYaeymEDFKTno1GiBuG_eT21_lRZBk1aJPEKmuiF1SVbqiT-KTwczgg1p1ZNcvEGTVB6K6kZy3Cr4uefLxK6AuQQ04t6KnM7zl3lmvn0wiQaHNzz6rkqqK3e3ojHVMWdb51mGtlkt1cEYGx1ZC7bOvnyFWMXHLIUx4HiajVAvC
# ...

# %%
count = 1
for i in image_url:
    #print(i)
    x =requests.get(i).content
    #print(i)
    
    f = open(os.path.join("abc", 'zedge' + str(count) + "_" + ".jpg"), 'wb')#using python to read and write in the file 
    f.write(x)
    f.close()
    count += 1

# %%
url = x.split("imageUrl")[1].split(',')[0]

# %%
urls = url[3:len(url)-1]

# %%
image_content =requests.get(urls).content

# %%
f = open(os.path.join("xyz", 'a' + "_" + ".jpg"), 'wb')#using python to read and write in the file 
               
f.write(image_content)
f.close()
